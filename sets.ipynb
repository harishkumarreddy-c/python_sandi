# %%
lMyList = [1, 2, 1, 3,3, 4, 5 ]
print(lMyList)
# Out:
# [1, 2, 1, 3, 3, 4, 5]

# %%
sMyValues = {1, 2, 1, 3,3, 4, 5 }
print(sMyValues)
print(type(sMyValues))
sMyValues.add(6)
print(sMyValues)
sMyValues.add(3)
print(sMyValues)
sMyValues.remove(2)
print(sMyValues)
print(sMyValues.union({7, 8, 9}))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}
# {1, 3, 4, 5, 6}
# {1, 3, 4, 5, 6, 7, 8, 9}

# %%
# myname = ""
myname = None
print(type(myname))
# Out:
# <class 'NoneType'>

# %%
# Case Sensitivity in Python

name = "Alice"
Name = "Bob"
print(name)  # Output: Alice
print(Name)  # Output: Bob

# "a" != "A"
# Out:
# Alice
# Bob
