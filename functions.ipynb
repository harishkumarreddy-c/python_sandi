# %%
def add_numbers():
    a,b = 5, 3
    c = a + b
    print(c)

add_numbers()
add_numbers()
add_numbers()
add_numbers()
add_numbers()
add_numbers()
# Out:
# 8
# 8
# 8
# 8
# 8
# 8

# %%
# Parameters and Arguments
def add2(a, b):
    c = a + b
    print(c)

# add2()
add2(5, 6)
add2(7, 8)
add2(9, 10)
add2(11, 12)
add2(13, 14)
# Out:
# 11
# 15
# 19
# 23
# 27

# %%
def add3(a, b):
    c = a + b
    return c

print(add3(5, 6))
res = add3(7, 8)
print(res)
# Out:
# 11
# 15
