# %%
x, y = 4,5

print(x, y)
# Out:
# 4 5

# %%
if x<y :
    print(f"{y} is bigger than {x}")
    print(f"{y} is bigger than {x}")
    print(f"{y} is bigger than {x}")
# Out:
# 5 is bigger than 4
# 5 is bigger than 4
# 5 is bigger than 4

# %%
if x>y :
    print(f"{x} is bigger than {y}")
else:
    print(f"{x} is not bigger than {y}")
# Out:
# 4 is not bigger than 5

# %%
x,y = 5,6

if x>y :
    print(f"{x} is bigger than {y}")
elif x==y:
    print(f"{x} and {y} are same!")
else:
    print(f"{x} is not bigger than {y}")
# Out:
# 5 is not bigger than 6

# %%
# x = None
x = 10
if x:
    if x>y :
        print(f"{x} is bigger than {y}")
    elif x==y:
        print(f"{x} and {y} are same!")
    else:
        print(f"{x} is not bigger than {y}")

# %%
x = 2
y = 0

# z = x/y

if y:
    z = x/y
else:
    print(f"Division cannot be possible with {y}")
# Out:
# Division cannot be possible with 0

# %%
x,y = 0,2
print( not x)
print( not not x) 

# bit level values : 0, 1
print(bool(0))
print(bool(1))


# if condition
# if x != None:
# if x == True
# if x:
if x != None and x != 0:
    print (x)
# Out:
# True
# False
# False
# True

# %%
if(1>2):
    print("1>2")
else:
    print("1<2")
finally:
    print("done")
# Out:
#   Cell In[2], line 5
#     finally:
#     ^
# SyntaxError: invalid syntax

# %%
# match case statement
month = 11
# month_name = ""
month_label = None

match month:
    case 1:
        month_label = "January"
    case 2:
        month_label = "February"
    case 3:
        month_label = "March"
    case 4:
        month_label = "April"
    case 5:
        month_label = "May"
    case 6:
        month_label = "June"
    case 7:
        month_label = "July"
    case 8:
        month_label = "August"
    case 9:
        month_label = "September"
    case 10:
        month_label = "October"
    case 11:
        month_label = "November"
    case 12:
        month_label = "December"

print(month_label)
# Out:
# November

# %%
# Ternary operator
x = 10
y = 20
is_bigger = True if x>y else False
print(is_bigger)
# Out:
# True
