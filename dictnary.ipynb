# %%
# simple Dictionary
mylist = ["Alice", 30, "New York", ["Python", "Data Science", "Machine Learning"], 95.5]

myDict = {
    "name": "Alice", 
    "age": 30, 
    "city": "New York",
    "skills": ["Python", "Data Science", "Machine Learning"],
    "score": 95.5
    }
print(myDict)
print(type(myDict))
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York', 'skills': ['Python', 'Data Science', 'Machine Learning'], 'score': 95.5}
# <class 'dict'>

# %%
print(mylist[0])  
print(myDict["name"])
print(myDict["skills"])

# print discriptive message
print(f"{myDict['name']} is {myDict['age']} years old and lives in {myDict['city']}.")
# Out:
# Alice
# Alice
# ['Python', 'Data Science', 'Machine Learning']
# Alice is 30 years old and lives in New York.

# %%
# getter and setter methods

print(myDict.get("name"))
myDict["name"] = "Bob"
print(myDict.get("name"))
# Out:
# Alice
# Bob

# %%
print(myDict["skills"])
# Out:
# ['Python', 'Data Science', 'Machine Learning']

# %%
print(myDict.get("skills")[2])
print(mylist[3][2])
# Out:
# Machine Learning
# Machine Learning

# %%
# print(myDict["dob"])
print(myDict.get("dob", "Not Found"))
# Out:
# Not Found

# %%
keys = myDict.keys()
values = myDict.values()

print(keys)
print(values)
# Out:
# dict_keys(['name', 'age', 'city', 'skills', 'score'])
# dict_values(['Bob', 30, 'New York', ['Python', 'Data Science', 'Machine Learning'], 95.5])

# %%
# Complex Dictionary
HistoricalData = {
    "alice": {
        "name": "Alice",
        "age": 30,
        "city": "New York",
        "skills": ["Python", "Data Science", "Machine Learning"],
        "score": 95.5,
        "history": {
            "education": {
                "degree": "Bachelor's",
                "major": "Computer Science",
                "university": "XYZ University"
            },
            "work_experience": [
                {"company": "ABC Corp", "role": "Data Analyst", "duration": "2 years"},
                {"company": "DEF Inc", "role": "Data Scientist", "duration": "3 years"}
            ],
            "candidature":{
                "2020":{
                    "position": "Data Analyst",
                    "company": "ABC Corp",
                    "status": "Hired",
                    "activities": {
                        "1-1-2020": "Applied for Data Analyst position at ABC Corp",
                        "5-1-2020": "Phone interview with ABC Corp",
                        "10-1-2020": "On-site interview with ABC Corp",
                        "15-1-2020": "Received job offer from ABC Corp",
                        "20-1-2020": {
                            "9:00": "Accepted job offer from ABC Corp",
                            "10:00": "Started working at ABC Corp",
                            "11:00": "Completed first project at ABC Corp",
                            "12:00": "Received positive feedback from manager at ABC Corp"
                        }
                    }
                }
            }
        }
    }
}

# %%
print(HistoricalData['alice']['name'])
print(HistoricalData['alice']['history']["candidature"]["2020"]["activities"]["20-1-2020"]["10:00"])
# Out:
# Alice
# Started working at ABC Corp
