# %%
x,y,z = 123, 456.789, "Hello, World!"

print(x)
print(y)
print(z)
# Out:
# 123
# 456.789
# Hello, World!

# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
b = "Hello, World!"
print(b[:5])
# Out:
# Hello
